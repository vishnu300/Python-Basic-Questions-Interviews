# %%
# import libaries and data set
import pandas as pd
import numpy as np

# %%
# data set will loading 
df = pd.read_csv('SampleStudyPy.csv')
df.head
# Out:
# <bound method NDFrame.head of       A01  1  25000  Asocciate DataScinetist
# 0     A02  2  30000     Junior DataScientist
# 1     A03  3  35000     Senior DataScientist
# 2     A04  4  30000              ML engineer
# 3     A05  5  55000       Senior ML engineer
# 4     A06  6  75000            DataScientist
# ..    ... ..    ...                      ...
# 194  A196  4  30000              ML engineer
# 195  A197  5  55000       Senior ML engineer
# 196  A198  6  75000              ML engineer
# 197  A199  1  25000  Asocciate DataScinetist
# 198  A200  2  30000     Junior DataScientist
#
# [199 rows x 4 columns]>

# %%
df.columns
# Out:
# Index(['A01', '1', '25000', 'Asocciate DataScinetist'], dtype='object')

# %%
d = {
    'ID': df['A01'],
    'Year_exp': df['1'],
    'Salary' : df['25000'],
    'Job_role': df['Asocciate DataScinetist']
}

# %%
data = pd.DataFrame(d)
data.head(3)
# Out:
#     ID  Year_exp  Salary              Job_role
# 0  A02         2   30000  Junior DataScientist
# 1  A03         3   35000  Senior DataScientist
# 2  A04         4   30000           ML engineer

# %%
data['Job_role'].value_counts()
# Out:
# Job_role
# ML engineer                49
# Junior DataScientist       34
# Senior DataScientist       33
# Senior ML engineer         33
# Asocciate DataScinetist    33
# DataScientist              17
# Name: count, dtype: int64

# %%
import sklearn 
from sklearn.naive_bayes import GaussianNB, MultinomialNB
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier,RandomForestRegressor
from sklearn.tree import DecisionTreeClassifier,DecisionTreeRegressor
from sklearn.svm import SVR,SVC
from sklearn.neighbors import KNeighborsClassifier, KNeighborsRegressor

# %%
# model traning....
from sklearn.model_selection import train_test_split

# %%
# models
naiveGauss = GaussianNB()
liner_mode = LinearRegression()
randam_cls = RandomForestClassifier()
randam_reg = RandomForestRegressor()
decision_tree = DecisionTreeClassifier()
svm =SVC()
knn_cls = KNeighborsClassifier()

# %%
# ValueError: could not convert string to float: 'A177'
# to import CountVectorizer
# from sklearn.feature_extraction.text import CountVectorizer
# converted_flot = CountVectorizer()

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
label =LabelEncoder()

data1 = data.apply(LabelEncoder().fit_transform)

# %%
x=data1.drop(columns='Year_exp',axis=1)
y=data1['Year_exp']

# %%
# model Buliding
x_train,x_test,y_train,y_test = train_test_split(x,y , random_state=12,test_size=0.4)

# %%
data1
# Out:
#       ID  Year_exp  Salary  Job_role
# 0      0         1       1         2
# 1      1         2       2         4
# 2      2         3       1         3
# 3      3         4       3         5
# 4      4         5       4         1
# ..   ...       ...     ...       ...
# 194  114         3       1         3
# 195  115         4       3         5
# 196  116         5       4         3
# 197  117         0       0         0
# 198  119         1       1         2
#
# [199 rows x 4 columns]

# %%
# from sklearn.pipeline import Pipeline
# clf = Pipeline([('vectorizer', LabelEncoder()),('Gb', GaussianNB())])

# %%
# Train model
model_nb = MultinomialNB()
model_nb.fit(x_train, y_train)
# Out:
# MultinomialNB()

# %%
from sklearn.metrics import accuracy_score, classification_report
#Evaluate model
y_pred = model_nb.predict(x_test)
print('Accuracy:', accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.4625
#               precision    recall  f1-score   support
#
#            0       1.00      0.93      0.97        15
#            1       0.29      0.50      0.36        12
#            2       0.25      0.20      0.22        15
#            3       0.60      0.21      0.32        14
#            4       0.23      0.38      0.29        13
#            5       1.00      0.55      0.71        11
#
#     accuracy                           0.46        80
#    macro avg       0.56      0.46      0.48        80
# weighted avg       0.56      0.46      0.48        80

# %%
# house Price Prediction
# Random forest 
#
